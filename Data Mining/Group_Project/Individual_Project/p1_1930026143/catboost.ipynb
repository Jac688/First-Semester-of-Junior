# %%
import numpy as np
import pandas as pd
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split

# %%
training  = pd.read_csv("./dataset/training.csv")
test = pd.read_csv("./dataset/test.csv")
train_attr, test_attr, train_target, test_target = train_test_split(training.iloc[:,:-1],training.iloc[:,-1],test_size=0.2 , random_state=3333)

# %%
test.iloc[:,:-1]
# Out:
#     buying  maint  doors persons lug_boot
# 0      low  vhigh      3    more      med
# 1    vhigh   high      2    more    small
# 2    vhigh    med  5more       4      med
# 3      med    med  5more       4    small
# 4     high    med      4       4    small
# ..     ...    ...    ...     ...      ...
# 474    low  vhigh      4       4      big
# 475    med  vhigh      3    more      big
# 476  vhigh    low      3       4      big
# 477    med  vhigh      2       2      med
# 478    med  vhigh      2       4      med
#
# [479 rows x 5 columns]

# %%
decision_feature = np.where(train_attr.dtypes != np.float)[0]
# The loss function is crossing entroy
# by default, the deepth is 16 which can effect the speed of convergence 
# With the increase of time, the convergence speed gradually slows down, and the final error is almost unchanged
catboost = CatBoostClassifier(iterations=100, depth=10,
                              cat_features=decision_feature,learning_rate=0.2, loss_function='Logloss',
                              logging_level='Verbose')
# Out:
# <ipython-input-4-aa657da18229>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   decision_feature = np.where(train_attr.dtypes != np.float)[0]

# %%
catboost.fit(train_attr,train_target,eval_set=(test_attr, test_target),plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.6248005	test: 0.6344902	best: 0.6344902 (0)	total: 153ms	remaining: 15.1s
# 1:	learn: 0.5463421	test: 0.5589811	best: 0.5589811 (1)	total: 163ms	remaining: 8s
# 2:	learn: 0.4874583	test: 0.5027422	best: 0.5027422 (2)	total: 173ms	remaining: 5.59s
# 3:	learn: 0.4446832	test: 0.4615921	best: 0.4615921 (3)	total: 186ms	remaining: 4.45s
# 4:	learn: 0.4107545	test: 0.4294556	best: 0.4294556 (4)	total: 200ms	remaining: 3.81s
# 5:	learn: 0.3875433	test: 0.4063128	best: 0.4063128 (5)	total: 220ms	remaining: 3.45s
# 6:	learn: 0.3668971	test: 0.3863050	best: 0.3863050 (6)	total: 240ms	remaining: 3.18s
# 7:	learn: 0.3496677	test: 0.3702826	best: 0.3702826 (7)	total: 254ms	remaining: 2.92s
# 8:	learn: 0.3307503	test: 0.3528102	best: 0.3528102 (8)	total: 279ms	remaining: 2.82s
# 9:	learn: 0.3178519	test: 0.3430082	best: 0.3430082 (9)	total: 302ms	remaining: 2.71s
# 10:	learn: 0.3025943	test: 0.3275478	best: 0.3275478 (10)	total: 337ms	remaining: 2.73s
# 11:	learn: 0.2873489	test: 0.3145673	best: 0.3145673 (11)	total: 373ms	remaining: 2.74s
# 12:	learn: 0.2701265	test: 0.3010904	best: 0.3010904 (12)	total: 416ms	remaining: 2.78s
# 13:	learn: 0.2551821	test: 0.2889794	best: 0.2889794 (13)	total: 447ms	remaining: 2.75s
# 14:	learn: 0.2447186	test: 0.2800465	best: 0.2800465 (14)	total: 470ms	remaining: 2.67s
# 15:	learn: 0.2377306	test: 0.2735877	best: 0.2735877 (15)	total: 516ms	remaining: 2.71s
# 16:	learn: 0.2289693	test: 0.2664812	best: 0.2664812 (16)	total: 534ms	remaining: 2.6s
# 17:	learn: 0.2211352	test: 0.2581440	best: 0.2581440 (17)	total: 574ms	remaining: 2.61s
# 77:	learn: 0.0830466	test: 0.1048681	best: 0.1048681 (77)	total: 3.72s	remaining: 1.05s
# 78:	learn: 0.0824760	test: 0.1040590	best: 0.1040590 (78)	total: 3.76s	remaining: 1000ms
# 79:	learn: 0.0816058	test: 0.1032034	best: 0.1032034 (79)	total: 3.81s	remaining: 952ms
# 80:	learn: 0.0806713	test: 0.1023917	best: 0.1023917 (80)	total: 3.86s	remaining: 905ms
# 81:	learn: 0.0798928	test: 0.1017054	best: 0.1017054 (81)	total: 3.9s	remaining: 857ms
# 82:	learn: 0.0793047	test: 0.1010993	best: 0.1010993 (82)	total: 3.95s	remaining: 809ms
# 83:	learn: 0.0784761	test: 0.1007632	best: 0.1007632 (83)	total: 4s	remaining: 762ms
# 84:	learn: 0.0777054	test: 0.1004569	best: 0.1004569 (84)	total: 4.04s	remaining: 714ms
# 85:	learn: 0.0771002	test: 0.0999696	best: 0.0999696 (85)	total: 4.09s	remaining: 665ms
# 86:	learn: 0.0765214	test: 0.0995360	best: 0.0995360 (86)	total: 4.13s	remaining: 618ms
# 87:	learn: 0.0759944	test: 0.0987126	best: 0.0987126 (87)	total: 4.18s	remaining: 570ms
# 88:	learn: 0.0755217	test: 0.0982590	best: 0.0982590 (88)	total: 4.23s	remaining: 523ms
# 89:	learn: 0.0749325	test: 0.0979526	best: 0.0979526 (89)	total: 4.27s	remaining: 474ms
# 90:	learn: 0.0744485	test: 0.0974689	best: 0.0974689 (90)	total: 4.32s	remaining: 428ms
# 91:	learn: 0.0737819	test: 0.0969542	best: 0.0969542 (91)	total: 4.37s	remaining: 380ms
# 92:	learn: 0.0731642	test: 0.0964969	best: 0.0964969 (92)	total: 4.42s	remaining: 333ms
# 93:	learn: 0.0725355	test: 0.0963189	best: 0.0963189 (93)	total: 4.47s	remaining: 286ms
# 94:	learn: 0.0720828	test: 0.0958765	best: 0.0958765 (94)	total: 4.51s	remaining: 238ms
# 95:	learn: 0.0714966	test: 0.0957127	best: 0.0957127 (95)	total: 4.57s	remaining: 190ms
# 96:	learn: 0.0707801	test: 0.0951252	best: 0.0951252 (96)	total: 4.61s	remaining: 143ms
# 97:	learn: 0.0701860	test: 0.0947055	best: 0.0947055 (97)	total: 4.66s	remaining: 95.2ms
# 98:	learn: 0.0697700	test: 0.0942809	best: 0.0942809 (98)	total: 4.71s	remaining: 47.5ms
# 99:	learn: 0.0691360	test: 0.0934664	best: 0.0934664 (99)	total: 4.75s	remaining: 0us
#
# bestTest = 0.09346636325
# bestIteration = 99

# %%
print(catboost.get_best_score())
# Out:
# {'learn': {'Logloss': 0.06913598855611111}, 'validation': {'Logloss': 0.09346636324631127}}

# %%
res_pred = catboost.predict(test).tolist()
res_des = pd.Series(res_pred).value_counts()
res_des[0]/res_des.sum(), res_des[1]/res_des.sum()
res_pred
# Out:
# ['unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'acc',
#  'acc',
#  'acc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'acc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'acc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'acc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'unacc',
#  'acc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'unacc',
#  'acc',
#  'acc',
#  'acc',
#  'unacc',
#  'unacc']

# %%
res_pred = catboost.predict(training.drop(['evaluation'], axis=1)).tolist()
res_ser = pd.Series(res_pred)

# %%
train_res = pd.DataFrame([res_ser,training['evaluation']]).T
train_res.columns = ['pred', 'actl']
train_res_des = train_res.value_counts()


# score with acc is negative and unacc is positive
TP = train_res_des['unacc']['unacc']
FN = train_res_des['acc']['unacc']
FP = train_res_des['unacc']['acc']
TN =  train_res_des['acc']['acc']
precision = TP/(TP+FP)
recall = TP/(TP+FN)
f_score = 2*precision*recall/(precision+recall)
accuracy = train_res[train_res['pred']==train_res['actl']].shape[0]/train_res.shape[0]
print("acc is positive and unacc is negative")
print('precision: ' + str(precision) + ', recall: ' + str(recall) + ', f_score: ' + str(f_score))

# acc is positive and unacc is negative
TP = train_res_des['acc']['acc']
FN = train_res_des['unacc']['acc']
FP = train_res_des['acc']['unacc']
TN =  train_res_des['unacc']['unacc']
precision = TP/(TP+FP)
recall = TP/(TP+FN)
f_score = 2*precision*recall/(precision+recall)
accuracy = train_res[train_res['pred']==train_res['actl']].shape[0]/train_res.shape[0]
print("acc is positive and unacc is negative")
print('precision: ' + str(precision) + ', recall: ' + str(recall) + ', f_score: ' + str(f_score))
# Out:
# acc is positive and unacc is negative
# precision: 0.990521327014218, recall: 0.9881796690307328, f_score: 0.9893491124260355
# acc is positive and unacc is negative
# precision: 0.9630996309963099, recall: 0.9702602230483272, f_score: 0.9666666666666667

# %%
test['evaluation'] = pd.Series(res_pred)
test.to_csv('test_catboost.csv')
